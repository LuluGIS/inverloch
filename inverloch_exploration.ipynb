# %%
import geopandas as gpd
import folium
import numpy as np
import pandas as pd
from branca.element import Template, MacroElement
from folium import plugins

# %%
marineMap = gpd.read_file('data/VIC_MARINE_HABITAT_MAP_2023_7844.geojson')
bathyContours = gpd.read_file('data/Contour_b20_vic_lidmb_all_7844.geojson')
zoiInverloch = gpd.read_file('data/zone_of_interest_7844.geojson')

# %%
marineMap.head()
# Out:
#    SITE_TYPE  SITPOSSRC  SIT_POSTYP  INSTRM_TYP  INSTRM_NM  PROJ_LABEL  \
# 0        NaN        NaN         NaN         NaN        NaN         NaN
# 1        NaN        NaN         NaN         NaN        NaN         NaN
# 2        NaN        NaN         NaN         NaN        NaN         NaN
# 3        NaN        NaN         NaN         NaN        NaN         NaN
# 4        NaN        NaN         NaN         NaN        NaN         NaN
#
#    PROJ_NAME  PROJ_CODE  LOC_NAME            METHOD  ... BIOTC_CDE  \
# 0        NaN        NaN       NaN  Predictive Model  ...     ba3.1
# 1        NaN        NaN       NaN  Predictive Model  ...     ba2.2
# 2        NaN        NaN       NaN  Predictive Model  ...     ba3.1
# 3        NaN        NaN       NaN  Predictive Model  ...     ba5.5
# 4        NaN        NaN       NaN  Predictive Model  ...     ba2.2
#
#       BIOT_LBL  BIOT_LVL  HAB3BIOCDE   HAB3BIOLBL  \
# 0  High energy         3       ba3.1  High energy
# ...

# %%
marineMap.crs
# Out:
# <Geographic 2D CRS: EPSG:7844>
# Name: GDA2020
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: Australia including Lord Howe Island, Macquarie Island, Ashmore and Cartier Islands, Christmas Island, Cocos (Keeling) Islands, Norfolk Island. All onshore and offshore.
# - bounds: (93.41, -60.55, 173.34, -8.47)
# Datum: Geocentric Datum of Australia 2020
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
marineMap.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2695 entries, 0 to 2694
# Data columns (total 39 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SITE_TYPE   0 non-null      float64
#  1   SITPOSSRC   0 non-null      float64
#  2   SIT_POSTYP  0 non-null      float64
#  3   INSTRM_TYP  0 non-null      float64
#  4   INSTRM_NM   0 non-null      float64
#  5   PROJ_LABEL  0 non-null      float64
#  6   PROJ_NAME   0 non-null      float64
#  7   PROJ_CODE   0 non-null      float64
#  8   LOC_NAME    0 non-null      float64
#  9   METHOD      2695 non-null   object
#  10  PERSON_OBS  2695 non-null   object
#  11  PERSON_SUP  2695 non-null   object
#  12  EVENT_NAME  0 non-null      float64
#  13  OBJ_TYPE    0 non-null      float64
#  14  OBJDATTYP   2695 non-null   object
#  15  OBJ_DIR     0 non-null      float64
#  16  TIME_OFFST  0 non-null      float64
#  17  GEOM_SRID   2695 non-null   int64
# ...

# %%
for col in marineMap.columns:
    print(col)
# Out:
# SITE_TYPE
# SITPOSSRC
# SIT_POSTYP
# INSTRM_TYP
# INSTRM_NM
# PROJ_LABEL
# PROJ_NAME
# PROJ_CODE
# LOC_NAME
# METHOD
# PERSON_OBS
# PERSON_SUP
# EVENT_NAME
# OBJ_TYPE
# OBJDATTYP
# OBJ_DIR
# TIME_OFFST
# GEOM_SRID
# IMAGE_REF
# SAMPLE_REF
# IMG_TIME
# COMMENT_
# ORG
# IS_PROTECT
# CREATED
# MODIFIED
# ACCESS_
# DIST_XYZ
# BIOT_TTL
# BIOTC_CDE
# BIOT_LBL
# BIOT_LVL
# HAB3BIOCDE
# HAB3BIOLBL
# HAB3BIOTTL
# ID
# HAB3BIOID
# BIOTIC_ID
# geometry

# %%
marineMap[['IS_PROTECT', 'BIOTC_CDE', 'BIOT_LBL', 'BIOT_LVL', 'HAB3BIOCDE', 'HAB3BIOLBL', 'HAB3BIOTTL']].head()
# Out:
#    IS_PROTECT BIOTC_CDE     BIOT_LBL  BIOT_LVL HAB3BIOCDE   HAB3BIOLBL  \
# 0           0     ba3.1  High energy         3      ba3.1  High energy
# 1           0     ba2.2         Sand         3      ba2.2         Sand
# 2           0     ba3.1  High energy         3      ba3.1  High energy
# 3           0     ba5.5   Rhodoliths         3      ba5.5   Rhodoliths
# 4           0     ba2.2         Sand         3      ba2.2         Sand
#
#                        HAB3BIOTTL
# 0  High energy infralittoral rock
# 1                   Littoral sand
# 2  High energy infralittoral rock
# 3      Sublittoral rhodolith beds
# 4                   Littoral sand

# %%
marineMap.HAB3BIOTTL.unique()
# Out:
# array(['High energy infralittoral rock', 'Littoral sand',
#        'Sublittoral rhodolith beds', 'Sublittoral sand and muddy sand',
#        'High energy littoral rock', 'Saltmarsh and reedbeds', nan,
#        'High energy open-coast circalittoral rock', 'Mangrove',
#        'Sublittoral seagrass beds', 'Moderate energy infralittoral rock'],
#       dtype=object)

# %%
marineMap['HAB3BIOTTL'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2695 entries, 0 to 2694
# Series name: HAB3BIOTTL
# Non-Null Count  Dtype
# --------------  -----
# 2538 non-null   object
# dtypes: object(1)
# memory usage: 21.2+ KB

# %%
marineMap.BIOT_LBL.unique()
# Out:
# array(['High energy', 'Sand', 'Rhodoliths', 'Saltmarsh', 'Unassigned',
#        'Mangrove', 'Seagrass', 'Moderate energy'], dtype=object)

# %%
marineMap.HAB3BIOLBL.unique()
# Out:
# array(['High energy', 'Sand', 'Rhodoliths', 'Saltmarsh', nan, 'Mangrove',
#        'Seagrass', 'Moderate energy'], dtype=object)

# %%
marineMap.IS_PROTECT.unique()
# Out:
# array([0])

# %%
marineMap.crs
# Out:
# <Geographic 2D CRS: EPSG:7844>
# Name: GDA2020
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: Australia including Lord Howe Island, Macquarie Island, Ashmore and Cartier Islands, Christmas Island, Cocos (Keeling) Islands, Norfolk Island. All onshore and offshore.
# - bounds: (93.41, -60.55, 173.34, -8.47)
# Datum: Geocentric Datum of Australia 2020
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
bathyContours.head()
# Out:
#      ID  CONTOUR                                           geometry
# 0  1044       -1  MULTILINESTRING ((145.72176 -38.64073, 145.721...
# 1  1045       -1  MULTILINESTRING ((145.71424 -38.64327, 145.714...
# 2  1047       -1  MULTILINESTRING ((145.71401 -38.64363, 145.714...
# 3  1057       -1  MULTILINESTRING ((145.72250 -38.64274, 145.722...
# 4  1058       -1  MULTILINESTRING ((145.72870 -38.64576, 145.728...

# %%
bathyContours.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        40 non-null     int64
#  1   CONTOUR   40 non-null     int64
#  2   geometry  40 non-null     geometry
# dtypes: geometry(1), int64(2)
# memory usage: 1.1 KB

# %%
bathyContours.crs
# Out:
# <Geographic 2D CRS: EPSG:7844>
# Name: GDA2020
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: Australia including Lord Howe Island, Macquarie Island, Ashmore and Cartier Islands, Christmas Island, Cocos (Keeling) Islands, Norfolk Island. All onshore and offshore.
# - bounds: (93.41, -60.55, 173.34, -8.47)
# Datum: Geocentric Datum of Australia 2020
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
zoiInverloch.head()
# Out:
#          PFI POSTCODE      PFI_CR        UFI      UFI_CR    UFI_OLD  \
# 0  205408026     3996  2005-09-27  499596510  2015-07-22  468438491
#
#                                             geometry
# 0  MULTIPOLYGON (((145.59305 -38.68694, 145.58948...

# %%
zoiInverloch['ZOI_INFO'] = '5km buffer zone around the postcode boundary of Inverloch (3996)'

# %%
zoiInverloch.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   PFI       1 non-null      object
#  1   POSTCODE  1 non-null      object
#  2   PFI_CR    1 non-null      object
#  3   UFI       1 non-null      int64
#  4   UFI_CR    1 non-null      object
#  5   UFI_OLD   1 non-null      int64
#  6   geometry  1 non-null      geometry
#  7   ZOI_INFO  1 non-null      object
# dtypes: geometry(1), int64(2), object(5)
# memory usage: 192.0+ bytes

# %%
zoiInverloch.crs
# Out:
# <Geographic 2D CRS: EPSG:7844>
# Name: GDA2020
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: Australia including Lord Howe Island, Macquarie Island, Ashmore and Cartier Islands, Christmas Island, Cocos (Keeling) Islands, Norfolk Island. All onshore and offshore.
# - bounds: (93.41, -60.55, 173.34, -8.47)
# Datum: Geocentric Datum of Australia 2020
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
marineMap['HAB3BIOTTL'] = marineMap['HAB3BIOTTL'].fillna('Uncategoried')
marineMap.HAB3BIOTTL.unique()
# Out:
# array(['High energy infralittoral rock', 'Littoral sand',
#        'Sublittoral rhodolith beds', 'Sublittoral sand and muddy sand',
#        'High energy littoral rock', 'Saltmarsh and reedbeds',
#        'Uncategoried', 'High energy open-coast circalittoral rock',
#        'Mangrove', 'Sublittoral seagrass beds',
#        'Moderate energy infralittoral rock'], dtype=object)

# %%
# Colour dictionary for biotope area title

biotopeTtl_dict = {'High energy infralittoral rock': '#c644c8',
                    'Littoral sand': '#d783aa',
                    'Sublittoral rhodolith beds': '#86e3cf', 
                    'Sublittoral sand and muddy sand': '#4553d1',
                    'High energy littoral rock': '#dca448', 
                    'Saltmarsh and reedbeds': '#793bc9',
                    'Uncategoried': '#000000',
                    'High energy open-coast circalittoral rock': '#d6817b', 
                    'Mangrove': '#f3f01d',
                    'Sublittoral seagrass beds': '#259ddd', 
                    'Moderate energy infralittoral rock': '#70d188'}

# %%
biotopeTtl_dict_2 = {'High energy infralittoral rock': 'red',
                    'Littoral sand': 'blue',
                    'Sublittoral rhodolith beds': 'purple', 
                    'Sublittoral sand and muddy sand': 'purple',
                    'High energy littoral rock': 'pink', 
                    'Saltmarsh and reedbeds': 'green',
                    'Uncategoried': 'black',
                    'High energy open-coast circalittoral rock': 'brown', 
                    'Mangrove': 'orange',
                    'Sublittoral seagrass beds': 'white', 
                    'Moderate energy infralittoral rock': 'grey'}

# %%
print(biotopeTtl_dict)
# Out:
# {'High energy infralittoral rock': '#c644c8', 'Littoral sand': '#d783aa', 'Sublittoral rhodolith beds': '#86e3cf', 'Sublittoral sand and muddy sand': '#4553d1', 'High energy littoral rock': '#dca448', 'Saltmarsh and reedbeds': '#793bc9', 'Uncategoried': '#000000', 'High energy open-coast circalittoral rock': '#d6817b', 'Mangrove': '#f3f01d', 'Sublittoral seagrass beds': '#259ddd', 'Moderate energy infralittoral rock': '#70d188'}

# %%
marineMap = marineMap.to_crs("EPSG:4326")
zoiInverloch = zoiInverloch.to_crs("EPSG:4326")
bathyContours = bathyContours.to_crs("EPSG:4326")
marineMap.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# Function to create marine habitat map

def inverloch_marine_map(marineMap, bathyContours, zoiInverloch):

    # Define location map and add basemaps as first layers
    loc_map = folium.Map(location = [-38.68898706877174, 145.72004848300898], zoom_start=11, tiles=None)
    # base maps
    folium.TileLayer(name='Open Street Map Standard', 
                     overlay=True, 
                     control=False, 
                     tiles='OpenStreetMap').add_to(loc_map)
    folium.TileLayer(name='Satellite overview', 
                     overlay=True, 
                     tiles='https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
                     attr='Tiles &copy; Esri &mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community').add_to(loc_map)
    
    # Add zone of interest boundaries
    zoneOfInterest = folium.FeatureGroup(name="Zone of interest", overlay=True)
    folium.GeoJson(zoiInverloch, 
                   style_function=lambda x:{'fillColor': False, 'color': '#ff0000', 'fillOpacity': 0.01, "dashArray": "5, 5",},
                   tooltip=folium.GeoJsonTooltip(fields=['ZOI_INFO'],
                                                 aliases=['Zone of interest info: '],
                                                 localize=True)).add_to(zoneOfInterest)
    zoneOfInterest.add_to(loc_map)
    
    # Define list for biotope hapitat groups
    biotopeHAB_lst = list(marineMap.HAB3BIOTTL.unique())
    # Iterate over list and assign polygons to groups
    for habitat in biotopeHAB_lst:
        # Each list index becomes a new group
        foliumMapGroup = folium.FeatureGroup(name=habitat, overlay=True)
        # Assign polygons to groups and define their colours 
        if habitat == 'High energy infralittoral rock':      
            folium.GeoJson(data=marineMap[(marineMap['HAB3BIOTTL'] == habitat)],
                            style_function=lambda x: {'fillColor': '#c644c8', 'color': '#c644c8', 'weight': 1,'fillOpacity': 0.7},
                            tooltip=folium.GeoJsonTooltip(
                            fields=['BIOTC_CDE', 'BIOT_LBL', 'BIOT_LVL', 'HAB3BIOTTL'],
                            aliases=['Biotope code: ', 'Biotope label: ', 'Biotope level: ', 'Biotope habitat title: '],
                            localize=True)).add_to(foliumMapGroup)
            
        if habitat == 'Littoral sand':      
            folium.GeoJson(data=marineMap[(marineMap['HAB3BIOTTL'] == habitat)],
                            style_function=lambda x: {'fillColor': '#d783aa', 'color': '#d783aa', 'weight': 1,'fillOpacity': 0.7},
                            tooltip=folium.GeoJsonTooltip(
                            fields=['BIOTC_CDE', 'BIOT_LBL', 'BIOT_LVL', 'HAB3BIOTTL'],
                            aliases=['Biotope code: ', 'Biotope label: ', 'Biotope level: ', 'Biotope habitat title: '],
                            localize=True)).add_to(foliumMapGroup)
            
        if habitat == 'Sublittoral rhodolith beds':      
            folium.GeoJson(data=marineMap[(marineMap['HAB3BIOTTL'] == habitat)],
                            style_function=lambda x: {'fillColor': '#86e3cf', 'color': '#86e3cf', 'weight': 1,'fillOpacity': 0.7},
                            tooltip=folium.GeoJsonTooltip(
                            fields=['BIOTC_CDE', 'BIOT_LBL', 'BIOT_LVL', 'HAB3BIOTTL'],
                            aliases=['Biotope code: ', 'Biotope label: ', 'Biotope level: ', 'Biotope habitat title: '],
                            localize=True)).add_to(foliumMapGroup)
            
        if habitat == 'Sublittoral sand and muddy sand':      
            folium.GeoJson(data=marineMap[(marineMap['HAB3BIOTTL'] == habitat)],
                            style_function=lambda x: {'fillColor': '#4553d1', 'color': '#4553d1', 'weight': 1,'fillOpacity': 0.7},
                            tooltip=folium.GeoJsonTooltip(
                            fields=['BIOTC_CDE', 'BIOT_LBL', 'BIOT_LVL', 'HAB3BIOTTL'],
                            aliases=['Biotope code: ', 'Biotope label: ', 'Biotope level: ', 'Biotope habitat title: '],
                            localize=True)).add_to(foliumMapGroup)
        
        if habitat == 'High energy littoral rock':      
            folium.GeoJson(data=marineMap[(marineMap['HAB3BIOTTL'] == habitat)],
                            style_function=lambda x: {'fillColor': '#dca448', 'color': '#dca448', 'weight': 1,'fillOpacity': 0.7},
                            tooltip=folium.GeoJsonTooltip(
                            fields=['BIOTC_CDE', 'BIOT_LBL', 'BIOT_LVL', 'HAB3BIOTTL'],
                            aliases=['Biotope code: ', 'Biotope label: ', 'Biotope level: ', 'Biotope habitat title: '],
                            localize=True)).add_to(foliumMapGroup)
            
        if habitat == 'Saltmarsh and reedbeds':      
            folium.GeoJson(data=marineMap[(marineMap['HAB3BIOTTL'] == habitat)],
                            style_function=lambda x: {'fillColor': '#793bc9', 'color': '#793bc9', 'weight': 1,'fillOpacity': 0.7},
                            tooltip=folium.GeoJsonTooltip(
                            fields=['BIOTC_CDE', 'BIOT_LBL', 'BIOT_LVL', 'HAB3BIOTTL'],
                            aliases=['Biotope code: ', 'Biotope label: ', 'Biotope level: ', 'Biotope habitat title: '],
                            localize=True)).add_to(foliumMapGroup)
            
        if habitat == 'Uncategoried':      
            folium.GeoJson(data=marineMap[(marineMap['HAB3BIOTTL'] == habitat)],
                            style_function=lambda x: {'fillColor': '#000000', 'color': '#000000', 'weight': 1,'fillOpacity': 0.7},
                            tooltip=folium.GeoJsonTooltip(
                            fields=['BIOTC_CDE', 'BIOT_LBL', 'BIOT_LVL', 'HAB3BIOTTL'],
                            aliases=['Biotope code: ', 'Biotope label: ', 'Biotope level: ', 'Biotope habitat title: '],
                            localize=True)).add_to(foliumMapGroup)
            
        if habitat == 'High energy open-coast circalittoral rock':      
            folium.GeoJson(data=marineMap[(marineMap['HAB3BIOTTL'] == habitat)],
                            style_function=lambda x: {'fillColor': '#d6817b', 'color': '#d6817b', 'weight': 1,'fillOpacity': 0.7},
                            tooltip=folium.GeoJsonTooltip(
                            fields=['BIOTC_CDE', 'BIOT_LBL', 'BIOT_LVL', 'HAB3BIOTTL'],
                            aliases=['Biotope code: ', 'Biotope label: ', 'Biotope level: ', 'Biotope habitat title: '],
                            localize=True)).add_to(foliumMapGroup)
            
        if habitat == 'Mangrove':      
            folium.GeoJson(data=marineMap[(marineMap['HAB3BIOTTL'] == habitat)],
                            style_function=lambda x: {'fillColor': '#f3f01d', 'color': '#f3f01d', 'weight': 1,'fillOpacity': 0.7},
                            tooltip=folium.GeoJsonTooltip(
                            fields=['BIOTC_CDE', 'BIOT_LBL', 'BIOT_LVL', 'HAB3BIOTTL'],
                            aliases=['Biotope code: ', 'Biotope label: ', 'Biotope level: ', 'Biotope habitat title: '],
                            localize=True)).add_to(foliumMapGroup)
            
        if habitat == 'Sublittoral seagrass beds':      
            folium.GeoJson(data=marineMap[(marineMap['HAB3BIOTTL'] == habitat)],
                            style_function=lambda x: {'fillColor': '#259ddd', 'color': '#259ddd', 'weight': 1,'fillOpacity': 0.7},
                            tooltip=folium.GeoJsonTooltip(
                            fields=['BIOTC_CDE', 'BIOT_LBL', 'BIOT_LVL', 'HAB3BIOTTL'],
                            aliases=['Biotope code: ', 'Biotope label: ', 'Biotope level: ', 'Biotope habitat title: '],
                            localize=True)).add_to(foliumMapGroup)
            
        if habitat == 'Moderate energy infralittoral rock':      
            folium.GeoJson(data=marineMap[(marineMap['HAB3BIOTTL'] == habitat)],
                            style_function=lambda x: {'fillColor': '#70d188', 'color': '#70d188', 'weight': 1,'fillOpacity': 0.7},
                            tooltip=folium.GeoJsonTooltip(
                            fields=['BIOTC_CDE', 'BIOT_LBL', 'BIOT_LVL', 'HAB3BIOTTL'],
                            aliases=['Biotope code: ', 'Biotope label: ', 'Biotope level: ', 'Biotope habitat title: '],
                            localize=True)).add_to(foliumMapGroup)
            
        # Add separate groups to map
        foliumMapGroup.add_to(loc_map)
    
    # Add bathymetric contours to indicate sea depth levels
    bathyCont = folium.FeatureGroup(name="Bathymetric contours", overlay=True)
    folium.GeoJson(bathyContours, 
                   style_function=lambda x:{'fillColor': '#ffffff', 'color': '#ffffff',
                   'weight': 2,
                   'fillOpacity':0.8},
                   tooltip=folium.GeoJsonTooltip(fields=['CONTOUR'],
                                                 aliases=['Depth: '],
                                                 localize=True)).add_to(bathyCont)
    bathyCont.add_to(loc_map)


    folium.LayerControl(collapsed=True).add_to(loc_map)

    # Build a dragable map-legend
    template = """
    {% macro html(this, kwargs) %}

    <!doctype html>
    <html lang="en">
    <head>
    <meta charset="utf-8">
    <meta name="viewport" content="width=device-width, initial-scale=1">
    <title>Inverloch's marine biotope habitats</title>
    <link rel="stylesheet" href="//code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css">

    <script src="https://code.jquery.com/jquery-1.12.4.js"></script>
    <script src="https://code.jquery.com/ui/1.12.1/jquery-ui.js"></script>
    
    <script>
    $( function() {
        $( "#maplegend" ).draggable({
                        start: function (event, ui) {
                            $(this).css({
                                right: "auto",
                                top: "auto",
                                bottom: "auto"
                            });
                        }
                    });
    });

    </script>
    </head>
    <body>

    
    <div id='maplegend' class='maplegend' 
        style='position: absolute; z-index:9999; border:2px solid grey; background-color:rgba(255, 255, 255, 0.8);
        border-radius:6px; padding: 10px; font-size:14px; right: 20px; bottom: 20px;'>

    <div class='legend-title'>Marine biotope habitats</div>
    <div class='legend-scale'>
    <ul class='legend-labels'> 
        <li><span style='background:#c644c8;opacity:0.7;'></span>High energy infralittoral rock</li>
        <li><span style='background:#d783aa;opacity:0.7;'></span>Littoral sand</li>
        <li><span style='background:#86e3cf;opacity:0.7;'></span>Sublittoral rhodolith beds</li>
        <li><span style='background:#4553d1;opacity:0.7;'></span>Sublittoral sand and muddy sand</li>
        <li><span style='background:#dca448;opacity:0.7;'></span>High energy littoral rock</li>
        <li><span style='background:#793bc9;opacity:0.7;'></span>Saltmarsh and reedbeds</li>
        <li><span style='background:#000000;opacity:0.7;'></span>Uncategoried</li>
        <li><span style='background:#d6817b;opacity:0.7;'></span>High energy open-coast circalittoral rockr</li>
        <li><span style='background:#f3f01d;opacity:0.7;'></span>Mangrove</li>
        <li><span style='background:#259ddd;opacity:0.7;'></span>Sublittoral seagrass beds</li>
        <li><span style='background:#70d188;opacity:0.7;'></span>Moderate energy infralittoral rock</li>
    </ul>
    <div class='legend-title'>Other</div>
    <ul class='legend-labels'>
        <li><span style='background:#ffffff;opacity:0.7;'></span>Bathymetric contours</li>
        <li><span style='background:#ff0000;opacity:0.7;'></span>Zone of interest</li>
    </ul> 

    </div>
    
    
    
    </body>
    </html>

    <style type='text/css'>
    .maplegend .legend-title {
        text-align: left;
        margin-bottom: 5px;
        font-weight: bold;
        font-size: 90%;
        }
    .maplegend .legend-scale ul {
        margin: 0;
        margin-bottom: 5px;
        padding: 0;
        float: left;
        list-style: none;
        }
    .maplegend .legend-scale ul li {
        font-size: 80%;
        list-style: none;
        margin-left: 0;
        line-height: 18px;
        margin-bottom: 2px;
        }
    .maplegend ul.legend-labels li span {
        display: block;
        float: left;
        height: 16px;
        width: 30px;
        margin-right: 5px;
        margin-left: 0;
        border: 1px solid #999;
        }
    .maplegend .legend-source {
        font-size: 80%;
        color: #777;
        clear: both;
        }
    .maplegend a {
        color: #777;
        }
    </style>
    {% endmacro %}"""

    macro = MacroElement()
    macro._template = Template(template)

    loc_map.get_root().add_child(macro)

    return loc_map



inverloch_marine_map(marineMap=marineMap, bathyContours=bathyContours, zoiInverloch=zoiInverloch).save('inverloch-marine-biotope-case-study-map.html')
